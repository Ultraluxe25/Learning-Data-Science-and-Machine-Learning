# %% [markdown]
# ![image.png](attachment:d193e75c-0183-4568-9c42-9537ec33e576.png)

# %% [markdown]
# ![image.png](attachment:b10cebf1-c768-4ba7-9c0b-40db72e45530.png)

# %% [markdown]
# ![image.png](attachment:e89bb5b4-a16e-4afd-8ee9-3afa8f0c9afb.png)

# %% [markdown]
# ![image.png](attachment:741761fe-d332-4e02-86da-e36fca39a13b.png)

# %% [markdown]
# ![image.png](attachment:21a2ea61-18f1-41f7-9ff7-493f3de6cfd3.png)
# ![image.png](attachment:08d17231-064f-4d57-a647-e460307ae637.png)

# %% [markdown]
# ![image.png](attachment:6d6687a6-3b30-43bc-9c21-e872d123a8bf.png)

# %% [markdown]
# ![image.png](attachment:a02a03dc-eb36-48c5-92ab-b3be1a9cb5b3.png)

# %% [markdown]
# ![image.png](attachment:60e50af2-b631-4f5b-8b39-7472509f6380.png)
# ### SageMaker for ML

# %% [markdown]
# ![image.png](attachment:3bc5b59c-1a2d-4e2d-bd7a-3fe17b661370.png)

# %% [markdown]
# ![image.png](attachment:81af148c-4fc2-4157-990a-67df3441bea7.png)

# %% [markdown]
# ![image.png](attachment:c0375d0c-aae5-4cc6-a9d4-dfd9c767e028.png)
#
# ![image.png](attachment:9da69f78-da76-4f03-9ef5-8c650366f839.png)
#
# ![image.png](attachment:5cdb2f70-26e3-4bba-a3b7-d9fc39913dc6.png)

# %% [markdown]
# ![image.png](attachment:b38b1afc-d324-4668-bff9-f175c5e1868a.png)

# %% [markdown]
# ![image.png](attachment:491b2bfe-0056-43f0-8f55-4fa7ca28ab9e.png)

# %% [markdown]
# ![image.png](attachment:58fb94c5-7e4f-43bf-aa0f-d4e6a2370eac.png)

# %% [markdown]
# ![image.png](attachment:6f4d7d97-e620-4a67-bbd8-6c8ef4435af4.png)
