# %% [markdown]
# ![image.png](attachment:cec2d706-2f06-4388-8e90-a866f3a7e0d7.png)

# %% [markdown]
# ![image.png](attachment:97d55042-6387-44fe-add6-380ed2ba1fa6.png)

# %% [markdown]
# ![image.png](attachment:44f948ec-5a51-484e-a898-6e4cf2d7429e.png)

# %% [markdown]
# ### h(x) - любая модель машинного обучения

# %% [markdown]
# ### Чаще всего бустинг собирают на деревьях решений

# %% [markdown]
# ### В бустингах деревья создаются последовательно, а не параллельно как в Случайном лесе

# %% [markdown]
# ![image.png](attachment:38ce0e72-78af-44dc-b7e6-3f4bfc887942.png)

# %% [markdown]
# ### Слабая модель - это простая модель, которая сама по себе не может дать хороший результат

# %% [markdown]
# ![image.png](attachment:fcc2b418-111f-46d7-9d15-75e3cd1f3573.png)

# %% [markdown]
# ### Бустинги - ансамбль из слабых последовательных моделей, каждая из которых учится на ошибках предыдущих

# %% [markdown]
# ### Бустинг - метод, а не алгоритм (модель) машинного обучения, который называется еще Meta Learning

# %% [markdown]
# # AdaBoost - Теория - Как работает адаптивный бустинг

# %% [markdown]
# ![image.png](attachment:2ccf4d0e-4843-490a-b265-b5d72d177c79.png)
# ### Деревьям (моделям), которые хорошо предсказывают значения целевой переменной ставят высокий альфа-тэ, а тем которые плохо - низкий

# %% [markdown]
# ![image.png](attachment:a9eaa9e4-3b02-498d-81c0-4171990fe1b5.png)

# %% [markdown]
# ![image.png](attachment:f549f170-8cae-48f0-b342-12d0cc439ab3.png)

# %% [markdown]
# ![image.png](attachment:1590cfe8-2598-4630-bc90-3e9514909ac4.png)

# %% [markdown]
# ### t также может быть номером дерева, которое обучается на ошибках предыдущих (номер дерева == итерация ансамбля)

# %% [markdown]
# ![image.png](attachment:4a0b1128-4bec-4b2a-8ad3-270b248ca3c1.png)

# %% [markdown]
# ![image.png](attachment:a0298bb4-ecd6-4dc3-96fa-d591787c7168.png)
# ### Всем неправильно классифицированным точках увеличиваем весовые коэффициенты, намекая следующей модели заострить внимание на этих точках.

# %% [markdown]
# ![image.png](attachment:e20f7b89-a2e5-4dfc-befd-5f7cf179f53a.png)
# ### Продолжаем много разных разбиений

# %% [markdown]
# ![image.png](attachment:0bb9257b-c515-4b9c-b315-12430ff35c04.png)

# %% [markdown]
# ![image.png](attachment:571272db-1c94-46dd-84b4-43acea986b73.png)
