# %% [markdown]
# ![image.png](attachment:b8b7f216-ecae-4397-8e4b-aade7dadd9e8.png)

# %% [markdown]
# # Модуль 9: Обзор Машинного обучения

# %% [markdown]
# ![image.png](attachment:45d024af-f09d-45ae-9c12-6094f7718b74.png)

# %% [markdown]
# ![image.png](attachment:6f4966c3-ae27-4145-81df-f062ddee3108.png)

# %% [markdown]
# ### Работа для R&D
# ![image.png](attachment:7fcad7a5-7a10-402e-a692-76baa70b1aca.png)

# %% [markdown]
# ![image.png](attachment:1abd69d9-fe78-4c62-a0e7-592efbd6b87e.png)

# %% [markdown]
# ![image.png](attachment:e917113e-f74d-4151-945f-6bf85fd62ca4.png)

# %% [markdown]
# ### Задачи разделов ML
# ![image.png](attachment:b252d82c-5cbc-49bb-ad09-56b6dab7f06f.png)

# %% [markdown]
# Fit - от слова "подгонка"

# %% [markdown]
# ![image.png](attachment:b18a01f8-e1e2-4622-97c2-bcd343794b3b.png)

# %% [markdown]
# В настройку модели входит подбор гиперпараметров

# %% [markdown]
# МНК применяют для нахождения коэффициентов при одной переменной, а метод градиентного спуска для нахождения коэффициентов в уравнении многих переменных

# %% [markdown]
# ### Двойной индекс для переменных
# ![image.png](attachment:ae58851d-4a29-4052-8494-affd7257e1ca.png)

# %% [markdown]
# ![image.png](attachment:6607d44a-c69c-4af9-875e-07a6aba5db87.png)
#
# Т.к. идеальных коэффициентов нет, то ещё можно прибавить к правой части эпсилон (ошибки модели). В данном случае игрик с крышечкой, т.к. это прогнозный игрик

# %% [markdown]
# ![image.png](attachment:3aca551e-60e5-4e68-9407-82701613159a.png)

# %% [markdown]
# ![image.png](attachment:f7c7d3db-18b0-4197-8a5c-42c5aeebd384.png)

# %% [markdown]
# ![image.png](attachment:c4522216-e231-457e-8cd3-9cfaa76b7e37.png)

# %% [markdown]
# ![image.png](attachment:80f86117-3b23-4c3c-8f16-07c74f651e8a.png)

# %% [markdown]
# ![image.png](attachment:f67e94a2-57f0-47fe-919e-26ce44139f5d.png)

# %% [markdown]
# ![image.png](attachment:4a7a5c2e-cc7c-4a9d-92f1-b4f1abc6b9eb.png)
