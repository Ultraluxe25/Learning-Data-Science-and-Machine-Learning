# %% [markdown]
# ![image.png](attachment:image.png)
#
# Статья в которой появилась идея градиентного спуска

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
#
# Это вместо того чтобы каждый раз искать лучшие параметры для всех моделей сразу. Мы ищем лучшие параметры только для последней на данной итерации модели.

# %% [markdown]
# ![image.png](attachment:image.png)
#
# Формула с марта 2023 (пятничная лекция с Максом из Сбера)
