# %% [markdown]
# ![image.png](attachment:90c6e35a-44fb-4ec7-877d-6cca3fc823cc.png)

# %% [markdown]
# ![image.png](attachment:180b8076-eeb9-41c3-8858-7c6814679af4.png)

# %% [markdown]
# ![image.png](attachment:19fb5ec8-39c9-48dd-b9ff-5d7ebd3680a5.png)

# %% [markdown]
# ![image.png](attachment:e4b09636-0735-40ab-b22f-eb3285c86175.png)

# %% [markdown]
# ![image.png](attachment:02b03452-4369-45f0-b12c-4e2395f2343a.png)

# %% [markdown]
# ![image.png](attachment:da5e677e-a6ac-4697-931a-2e4f6091f458.png)

# %% [markdown]
# ![image.png](attachment:92f37c9a-d9f6-4460-98aa-fb5609119c0a.png)

# %%
import numpy as np

w = np.array([15/7, -9/7, -1])
x_test = np.array([(-8, -4), (-2, 2), (4, 8), (6, 3)]) # задайте самостоятельно (признаки образов: x0, x1, x2)
y_test = np.array([1, 1, -1, -1]) # задайте самостоятельно (метки класса)

# здесь продолжайте программу
margin = []
for i in range(len(x_test)):
    X = np.array([1, x_test[i][0], x_test[i][1]])
    a_x = X.T @ w
    Mi = a_x * y_test[i]
    margin.append(Mi)

# %% [markdown]
# ![image.png](attachment:21b04916-fba3-438b-9bd7-c5685d5681af.png)

# %% [markdown]
# ![image.png](attachment:d76c08d4-98ab-43e6-b236-46175a216929.png)

# %% [markdown]
# ![image.png](attachment:227fe79e-5141-4388-a667-5d6b2562dd49.png)

# %%
import numpy as np

w = np.array([-16, -4, 9]) # задайте самостоятельно (параметры модели: w0, w1, w2 - ориентация разделяющей линии)
x_test = np.array([(-5, 2), (-4, 6), (3, 2), (3, -3), (5, 6), (9, 2)]) # задайте самостоятельно (признаки образов: x0, x1, x2)
y_test = np.array([1, 1, 1, -1, -1, -1]) # задайте самостоятельно (метки класса)

# здесь продолжайте программу
margin = []
for i in range(len(x_test)):
    X = np.array([1, x_test[i][0], x_test[i][1]])
    a_x = X.T @ w
    Mi = a_x * y_test[i]
    margin.append(Mi)

# %% [markdown]
# ![image.png](attachment:ce69fc40-ce8e-4ba7-bf2b-4b2fdb33e39d.png)

# %% [markdown]
# ![image.png](attachment:4b7e2ca7-b53b-4727-a981-113d78383e2d.png)

# %%
import numpy as np

x_test = np.array([(-5, 2), (-4, 6), (3, 2), (3, -3), (5, 5), (5, 2), (-1, 3)])
y_test = np.array([1, 1, 1, -1, -1, -1, -1])
w = np.array([-8/3, -2/3, 1])

# здесь продолжайте программу
margin = []
for i in range(len(x_test)):
    X = np.array([1, x_test[i, 0], x_test[i, 1]])
    a_x = X.T @ w
    margin.append(a_x * y_test[i] < 0)

# print(margin)    
Q = np.array(margin).sum()
print(Q)
# Out:
# 2

# %% [markdown]
# ![image.png](attachment:bcbbdc52-eb64-4546-9d2d-11331d9c4953.png)

# %% [markdown]
# ![image.png](attachment:63bf45f4-7d7a-4ed3-9a05-19a1686e268a.png)

# %% [markdown]
# ![image.png](attachment:e9aa00ee-287e-4bf0-8b15-43c68048da8c.png)
