# %% [markdown]
# ![image.png](attachment:d2da8b94-96e5-402f-9f22-3021f19272c8.png)
# https://www.kaggle.com/datasets/adityadesai13/used-car-dataset-ford-and-mercedes

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# %%
bmw = pd.read_csv('datasets/bmw.csv')
bmw.head()
# Out:
#        model  year  price transmission  mileage fuelType  tax   mpg  \
# 0   5 Series  2014  11200    Automatic    67068   Diesel  125  57.6
# 1   6 Series  2018  27000    Automatic    14827   Petrol  145  42.8
# 2   5 Series  2016  16000    Automatic    62794   Diesel  160  51.4
# 3   1 Series  2017  12750    Automatic    26676   Diesel  145  72.4
# 4   7 Series  2014  14500    Automatic    39554   Diesel  160  50.4
#
#    engineSize
# 0         2.0
# 1         2.0
# 2         3.0
# 3         1.5
# 4         3.0

# %%
bmw.shape
# Out:
# (10781, 9)

# %%
train, test = train_test_split(bmw, random_state=29)

# %%
train.isna().sum()
# Out:
# model           0
# year            0
# price           0
# transmission    0
# mileage         0
# fuelType        0
# tax             0
# mpg             0
# engineSize      0
# dtype: int64

# %% [markdown]
# There is no missing data

# %%
plt.style.use('dark_background')
train['price'].hist(bins=20, legend=True);

# %%
y_train = train['price']
y_train.describe()
# Out:
# count      8085.00000
# mean      22791.26543
# std       11399.25104
# min        1200.00000
# 25%       14980.00000
# 50%       20491.00000
# 75%       27980.00000
# max      123456.00000
# Name: price, dtype: float64

# %% [markdown]
# ### Mean always bigger than median if distribution has long right tail (right-skewed).

# %% [markdown]
# Mean and Median BWM prices for each year

# %%
train.groupby('year')['price'].agg(['count', 'mean', 'median'])
# Out:
#       count          mean   median
# year
# 1996      1   5995.000000   5995.0
# 1997      1   3950.000000   3950.0
# 1998      1   3950.000000   3950.0
# 1999      4   3285.000000   3972.5
# 2000      2   1624.500000   1624.5
# 2001      3   7333.333333   5950.0
# 2002      5   3584.800000   2990.0
# 2003      2   9222.500000   9222.5
# 2004      9   8052.000000   3495.0
# 2005      5   5332.600000   4375.0
# 2006      8   6394.375000   4242.5
# 2007     13   4159.461538   3885.0
# 2008     14   6527.000000   5987.5
# 2009     25   7043.120000   5995.0
# 2010     30   7506.933333   6837.5
# 2011     36   9431.500000   8485.0
# 2012     84   9566.714286   8990.0
# 2013    259  11107.679537  10495.0
# 2014    362  13312.618785  12800.0
# 2015    690  15217.228986  13999.5
# 2016   1383  16606.558207  15800.0
# 2017   1324  19234.077039  18490.0
# 2018    619  22835.995153  21300.0
# 2019   2660  30967.869925  27990.0
# 2020    545  35229.025688  32583.0

# %% [markdown]
# In some years, there are very few observations (only 1 to 5).

# %%
train.groupby('year')['price'].median().plot();
