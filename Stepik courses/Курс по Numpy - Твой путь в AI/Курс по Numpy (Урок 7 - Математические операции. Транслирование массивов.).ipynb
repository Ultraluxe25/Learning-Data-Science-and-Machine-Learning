# %% [markdown]
# ![image.png](attachment:a14880c6-5256-4d1d-bc7a-3b2095b87c30.png)

# %% [markdown]
# ![image.png](attachment:45af22e4-c74e-47ca-b984-64e0c4e6dd76.png)

# %% [markdown]
# ![image.png](attachment:bbfd94f6-9f13-4341-a85d-5321b58f06b8.png)

# %% [markdown]
# ![image.png](attachment:07f2db3a-2c14-42eb-b932-ba09f86f83fa.png)

# %% [markdown]
# ![image.png](attachment:3f1bb7ca-a1f5-4e4c-9282-6682f600ed50.png)

# %% [markdown]
# ![image.png](attachment:75d88309-e17e-4410-a436-6ea9808ed125.png)

# %% [markdown]
# ![image.png](attachment:a1cba1fc-f760-41f0-b048-aaef46282b18.png)

# %% [markdown]
# ![image.png](attachment:d102de2a-7479-4f63-a775-afa12aabeb64.png)

# %% [markdown]
# ![image.png](attachment:3e718f38-a28c-4242-9d93-22fbf3b6c556.png)

# %% [markdown]
# ![image.png](attachment:7df60595-603b-4da6-8397-5eb4b1a329c2.png)

# %% [markdown]
# ![image.png](attachment:63d15526-ecae-4f87-a9ed-659bb4e918ba.png)

# %% [markdown]
# ![image.png](attachment:258fcbda-1d58-4113-a72e-5e86b6b6fc8f.png)

# %% [markdown]
# ![image.png](attachment:95d17228-c65e-460d-aefd-089241de2dc0.png)

# %% [markdown]
# ![image.png](attachment:5ea73e3f-49f6-4025-8a47-db9b34c779a4.png)

# %% [markdown]
# ![image.png](attachment:3303ab61-03d2-4442-9e03-67287d5235b9.png)

# %% [markdown]
# ![image.png](attachment:8f9f9372-c7e2-4340-9f8c-bac01aedd8fd.png)
