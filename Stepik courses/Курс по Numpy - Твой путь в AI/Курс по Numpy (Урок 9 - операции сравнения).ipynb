# %% [markdown]
# ![image.png](attachment:997e68a6-2ba0-4292-a4da-5d4017c11900.png)

# %% [markdown]
# ![image.png](attachment:e1e69e7c-c1cb-49bc-9106-ebe482b4562e.png)
# ![image.png](attachment:37ac8890-1e09-41f9-a23c-051a85269f87.png)

# %% [markdown]
# ![image.png](attachment:917b9f10-14aa-4e01-991a-7754b1fda0b6.png)
# ![image.png](attachment:c00d4321-ff97-4449-87fb-b69de70b811b.png)

# %% [markdown]
# ![image.png](attachment:7d718956-836c-4851-a6ef-2b02d1e07ca4.png)
# ![image.png](attachment:f04676f8-6b59-46c7-9124-de670cf37f52.png)

# %% [markdown]
# ![image.png](attachment:f88f16b1-f723-47b3-8a3e-4c6173294aa0.png)
# ![image.png](attachment:4ac9f9ef-7c66-42e4-b423-64a343e60db1.png)

# %% [markdown]
# ![image.png](attachment:c3eae369-6098-4a60-81c8-0dcbd24ccc2f.png)
# ![image.png](attachment:80d0b5e3-4815-46ca-b0ab-2f0224d8a5bb.png)

# %% [markdown]
# ![image.png](attachment:9f077ba1-bf1b-490a-b57f-dd4b06db641b.png)
# ![image.png](attachment:924534de-1e6f-49a3-a9be-e536ebd454b4.png)

# %% [markdown]
# ![image.png](attachment:3b2465fb-484d-4814-a657-ad88514a84f8.png)
# ![image.png](attachment:2209677d-01e2-4738-b3e0-716c14769985.png)

# %% [markdown]
# ![image.png](attachment:7f186d32-08b6-44e2-aac6-d45a2abefa9a.png)
# ![image.png](attachment:6026f7c9-385d-41a0-9ade-aa1df4240e75.png)

# %% [markdown]
# ![image.png](attachment:3391fd45-da2d-4703-bed5-c0cdbc65eb20.png)

# %% [markdown]
# ![image.png](attachment:518c126f-862a-49c1-a925-ca4ba0e34496.png)

# %% [markdown]
# ![image.png](attachment:cbb6c4e1-df32-4615-8b45-2ae8b5a3085f.png)
