# %% [markdown]
# ### На Windows можно ставить локальное окружение через pip, conda, uv

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### На Linux очень удобно через pyenv

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
