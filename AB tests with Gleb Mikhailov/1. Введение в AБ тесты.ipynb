# %% [markdown]
# ![image.png](attachment:153480d2-9b72-4f47-9443-a0aaee69d2e2.png)

# %% [markdown]
# ### Глеб рекомендует снимать вступление и заключение к курсу уже после того как курс готов, потому что изначальная структура может несколько раз поменяться как и начало с концом

# %% [markdown]
# ![image.png](attachment:29e198e5-4ac2-4353-8c09-23546add39fa.png)

# %% [markdown]
# # A/B Тесты - это метод проверки гипотез (идей) с помощью эксперимента (статистического теста)

# %% [markdown]
# ### Размер конверсии сайта в покупку (3%), означает что 3% посетивших сайт людей, сделали покупку

# %% [markdown]
# ![image.png](attachment:4a462cf9-1f6b-4ebe-b797-74d9f769e9c0.png)

# %% [markdown]
# ### Нужно учесть, составляю гипотезу, как изменение конкретного фактора повлияет на картину в целом, при неизменности влияния остальных факторов

# %% [markdown]
# ### Нужно учесть поправку на случайность

# %% [markdown]
# ### Группа А - текущая ситуация, группа B - прогнозируемая ситуация (гипотеза улучшения при переходе от А к B)

# %% [markdown]
# # Группа А - контрольная, группа В - тестовая

# %% [markdown]
# ![image.png](attachment:14213f29-fdb8-4a7d-992f-f57ab1a0a059.png)

# %% [markdown]
# ### Нужно суметь изолироваться от внешних факторов, но случайность все равно будет влиять на результат

# %% [markdown]
# # A/B тестирование - методология проверки гипотез с помощью эксперимента и статистики

# %% [markdown]
# ![image.png](attachment:ffb93c83-0b32-4a92-902b-8bb2932a9cab.png)

# %% [markdown]
# ![image.png](attachment:72d12287-1d8c-4c29-937c-e3bd192073a7.png)
# ### Собираем доказательства и анализируем их силу

# %% [markdown]
# ### На выходе A/B теста мы получаем решение (работает или нет) и метрики, которых характеризуют уверенность в этом решении

# %% [markdown]
# ### Пример 1: пациентам А дают лекарство, а пациентам В нет и смотрим как они выздаравливают

# %% [markdown]
# ![image.png](attachment:518b2ab6-6d3b-4336-8651-82e75a5cc131.png)
